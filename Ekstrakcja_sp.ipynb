# %%
import xmltodict
import pandas as pd

# %%
path = r"C:\Users\bekert\OneDrive - KPMG\Documents\python\wypakowywanie_sprawek_krs\e-sprawozdanie 2023 NS.xml"
with open(path,encoding="utf8") as f:
    data = xmltodict.parse(f.read())

# %%
def find_key(dict_:dict,search:str) ->str:
    for key in dict_.keys():
        if search in key:
            return key
        
    raise Exception("Brak szukanej frazy w slowniku")

# %%
# Out:
# dict_keys(['jin:RZiSKalk'])

# %%
jdn_inna = find_key(data,"JednostkaI")
bilans = find_key(data[jdn_inna],"Bilans")
aktywa = find_key(data[jdn_inna][bilans],"Aktywa")
pasywa = find_key(data[jdn_inna][bilans],"Pasywa")
pl_1=find_key(data[jdn_inna],"RZiS")
pl_2=find_key(data[jdn_inna][pl_1],"RZiS")

# %%
def clean_face(face):
    if ":" in face:
        return face.split(":")[-1]
    else:
        return face
        
def upacked_dict(nested_dict,face=""):
    for face0 in nested_dict.keys():
        if face:
            final_face = f"{face}|{clean_face(face0)}"
        else:
            final_face =  f"{clean_face(face0)}"
        if "Kwota" in face0:
            yield (f"{final_face}|{nested_dict[face0]}")
        else:
            yield from upacked_dict(nested_dict[face0],final_face)

# %%
def get_dataset(list,type):
    temp_dict = {"typKwota":[],"value":[],"face1":[],"face2":[],"face3":[],"face4":[],"face5":[],"face6":[]}
    for row in list:
        *faces, typKwota, value = row.split("|")
        faces = (faces+[""]*6)[:6]
        for i,face in enumerate(faces,1):
            temp_dict[f"face{i}"].append(face)
        temp_dict["typKwota"].append(typKwota)
        temp_dict["value"].append(value)
    df = pd.DataFrame(temp_dict)
    df['Type'] = type
    df['value'] = pd.to_numeric(df['value'])
    return df.pivot(index=['face1','face2','face3','face4','face5','face6','Type'],columns=['typKwota'],values='value').reset_index()

# %%
pl = list(upacked_dict(data[jdn_inna][pl_1][pl_2]))
bs_aktywa = list(upacked_dict(data[jdn_inna][bilans][aktywa]))
bs_pasywa = list(upacked_dict(data[jdn_inna][bilans][pasywa]))

# %%
df_bs_a = get_dataset(pl,"pl")

# %%
df_bs_a
# Out:
# typKwota face1  face2   face3 face4 face5 face6 Type        KwotaA  \
# 0            A                                    pl  8.704312e+08
# 1            A    A_I                             pl  8.187429e+08
# 2            A   A_II                             pl  5.168828e+07
# 3            A    A_J                             pl  5.023366e+08
# 4            B                                    pl  6.221346e+08
# 5            B    B_I                             pl  5.812400e+08
# 6            B   B_II                             pl  4.089468e+07
# 7            B    B_J                             pl  3.882584e+08
# 8            C                                    pl  2.482966e+08
# 9            D                                    pl  1.214860e+08
# 10           E                                    pl  6.286578e+07
# 11           F                                    pl  6.394479e+07
# 12           G                                    pl  5.703434e+06
# 13           G    G_I                             pl  1.548156e+06
# 14           G   G_II                             pl  2.171762e+06
# 15           G  G_III                             pl  0.000000e+00
# 16           G   G_IV                             pl  1.983516e+06
# 17           H                                    pl  5.746841e+07
# 18           H    H_I                             pl  0.000000e+00
# 19           H   H_II                             pl  1.326632e+06
# 20           H  H_III                             pl  5.614178e+07
# 21           I                                    pl  1.217982e+07
# 22           J                                    pl  5.786990e+07
# 23           J    J_I                             pl  2.463818e+07
# 24           J    J_I   J_I_A                     pl  2.463818e+07
# 25           J   J_II                             pl  6.655019e+05
# 26           J   J_II  J_II_J                     pl  6.286962e+05
# 27           J  J_III                             pl  0.000000e+00
# 28           J    J_V                             pl  3.256622e+07
# 29           K                                    pl  3.764755e+07
# 30           K    K_I                             pl  3.364755e+07
# 31           K    K_I   K_I_J                     pl  2.252796e+07
# 32           K   K_II                             pl  0.000000e+00
# 33           K  K_III                             pl  4.000000e+06
# 34           K   K_IV                             pl  0.000000e+00
# 35           L                                    pl  3.240217e+07
# 36           M                                    pl  6.652581e+06
# 37           O                                    pl  2.574958e+07
#
# typKwota        KwotaB
# 0         1.007315e+09
# 1         9.399368e+08
# 2         6.737868e+07
# 3         5.752679e+08
# 4         7.512264e+08
# 5         6.984242e+08
# 6         5.280212e+07
# 7         4.629189e+08
# 8         2.560891e+08
# 9         1.335486e+08
# 10        5.438383e+07
# 11        6.815665e+07
# 12        1.061635e+07
# 13        5.379254e+06
# 14        2.448892e+06
# 15        0.000000e+00
# 16        2.788206e+06
# 17        4.366373e+07
# 18        0.000000e+00
# 19        3.710236e+06
# 20        3.995349e+07
# 21        3.510927e+07
# 22        2.728523e+07
# 23        2.626948e+07
# 24        2.626948e+07
# 25        1.013558e+06
# 26        1.011315e+06
# 27        0.000000e+00
# 28        2.197430e+03
# 29        4.045161e+07
# 30        1.571159e+07
# 31        9.879870e+06
# 32        0.000000e+00
# 33        1.422300e+07
# 34        1.051702e+07
# 35        2.194290e+07
# 36        1.531794e+06
# 37        2.041111e+07

# %%
data[jdn_inna]
# Out:
# {'@xmlns:etd': 'http://crd.gov.pl/xml/schematy/dziedzinowe/mf/2016/01/25/eD/DefinicjeTypy/',
#  '@xmlns:dtsf': 'http://www.mf.gov.pl/schematy/SF/DefinicjeTypySprawozdaniaFinansowe/2018/07/09/DefinicjeTypySprawozdaniaFinansowe/',
#  '@xmlns:jin': 'http://www.mf.gov.pl/schematy/SF/DefinicjeTypySprawozdaniaFinansowe/2018/07/09/JednostkaInnaStruktury',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@xsi:schemaLocation': 'http://www.mf.gov.pl/schematy/SF/DefinicjeTypySprawozdaniaFinansowe/2018/07/09/JednostkaInnaWZlotych https://www.gov.pl/documents/2034621/2182793/JednostkaInnaWZlotych(1)_v1-2.xsd',
#  '@xmlns': 'http://www.mf.gov.pl/schematy/SF/DefinicjeTypySprawozdaniaFinansowe/2018/07/09/JednostkaInnaWZlotych',
#  'Naglowek': {'dtsf:OkresOd': '2023-01-01',
#   'dtsf:OkresDo': '2023-12-31',
#   'dtsf:DataSporzadzenia': '2024-03-28',
#   'jin:KodSprawozdania': {'@kodSystemowy': 'SFJINZ (1)',
#    '@wersjaSchemy': '1-2',
#    '#text': 'SprFinJednostkaInnaWZlotych'},
#   'jin:WariantSprawozdania': '1'},
#  'WprowadzenieDoSprawozdaniaFinansowego': {'P_1': {'P_1A': {'dtsf:NazwaFirmy': 'Nowy Styl Spółka z ograniczoną odpowiedzialnością',
#     'dtsf:Siedziba': {'dtsf:Wojewodztwo': 'podkarpackie',
#      'dtsf:Powiat': 'Krosno',
#      'dtsf:Gmina': 'Krosno',
#      'dtsf:Miejscowosc': 'Krosno'}},
#    'P_1B': {'dtsf:Adres': {'dtsf:KodKraju': 'PL',
#      'dtsf:Wojewodztwo': 'podkarpackie',
#      'dtsf:Powiat': 'Krosno',
#      'dtsf:Gmina': 'Krosno',
#      'dtsf:Ulica': 'Pużaka',
#      'dtsf:NrDomu': '49',
#      'dtsf:Miejscowosc': 'Krosno',
#      'dtsf:KodPocztowy': '38-400',
#      'dtsf:Poczta': 'Krosno'}},
#    'P_1C': {'dtsf:KodPKD': '3101Z'},
#    'P_1D': '6840009302',
#    'P_1E': '0000077550'},
#   'P_3': {'dtsf:DataOd': '2023-01-01', 'dtsf:DataDo': '2023-12-31'},
#   'P_4': 'false',
#   'P_5': {'P_5A': 'true', 'P_5B': 'true'},
#   'P_7': {'P_7A': 'Informacje dotyczące przyjętych zasad (polityki) rachunkowości zamieszczono w załączniku "Informacja dodatkowa.pdf" od strony nr 4 do 10',
#    'P_7B': 'Metody wyceny aktywów i pasywów zawarto w załączniku "Informacja dodatkowa.pdf" od strony nr 4 do 10',
#    'P_7C': 'Na wynik finansowy składa się: wynik na sprzedaży, wynik na pozostałej działalności operacyjnej, wynik na działalności finansowej, obowiązkowe obciążenie wyniku. Spółka stosuje metodę kalkulacyjną pomiaru wyniku finansowego.',
#    'P_7D': 'Sprawozdanie finansowe zostało sporządzone zgodnie z Ustawą z dnia 29 września 1994 roku o rachunkowości (tekst jednolity - Dz. U. z 2021 poz 237), według zasady\nkosztu historycznego.'}},
#  'Bilans': {'jin:Aktywa': {'dtsf:KwotaA': '925909224.68',
#    'dtsf:KwotaB': '997934308.34',
#    'jin:Aktywa_A': {'dtsf:KwotaA': '621391049.7',
#     'dtsf:KwotaB': '653789566.04',
#     'jin:Aktywa_A_I': {'dtsf:KwotaA': '20450414.75',
#      'dtsf:KwotaB': '12104725.72',
#      'jin:Aktywa_A_I_1': {'dtsf:KwotaA': '15941439.27',
#       'dtsf:KwotaB': '4791717.45'},
#      'jin:Aktywa_A_I_3': {'dtsf:KwotaA': '4508975.48',
#       'dtsf:KwotaB': '7313008.27'}},
#     'jin:Aktywa_A_II': {'dtsf:KwotaA': '344371056.25',
#      'dtsf:KwotaB': '344884074.57',
#      'jin:Aktywa_A_II_1': {'dtsf:KwotaA': '320790444.42',
#       'dtsf:KwotaB': '320144921.62',
#       'jin:Aktywa_A_II_1_A': {'dtsf:KwotaA': '9663171.82',
#        'dtsf:KwotaB': '13901504.02'},
#       'jin:Aktywa_A_II_1_B': {'dtsf:KwotaA': '186459466.51',
#        'dtsf:KwotaB': '181219939.62'},
#       'jin:Aktywa_A_II_1_C': {'dtsf:KwotaA': '112560968.13',
#        'dtsf:KwotaB': '113783326.22'},
#       'jin:Aktywa_A_II_1_D': {'dtsf:KwotaA': '4117652.44',
#        'dtsf:KwotaB': '2520946.3'},
#       'jin:Aktywa_A_II_1_E': {'dtsf:KwotaA': '7989185.52',
#        'dtsf:KwotaB': '8719205.46'}},
#      'jin:Aktywa_A_II_2': {'dtsf:KwotaA': '23576079.31',
#       'dtsf:KwotaB': '24739152.95'},
#      'jin:Aktywa_A_II_3': {'dtsf:KwotaA': '4532.52', 'dtsf:KwotaB': '0'}},
#     'jin:Aktywa_A_III': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
{'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#     'jin:J_V': {'dtsf:KwotaA': '32566217.56', 'dtsf:KwotaB': '2197.43'}},
#    'jin:K': {'dtsf:KwotaA': '37647548.6',
#     'dtsf:KwotaB': '40451606.08',
#     'jin:K_I': {'dtsf:KwotaA': '33647548.6',
#      'dtsf:KwotaB': '15711585.94',
#      'jin:K_I_J': {'dtsf:KwotaA': '22527960.04', 'dtsf:KwotaB': '9879870.43'}},
#     'jin:K_II': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#     'jin:K_III': {'dtsf:KwotaA': '4000000', 'dtsf:KwotaB': '14223000'},
#     'jin:K_IV': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '10517020.14'}},
#    'jin:L': {'dtsf:KwotaA': '32402165.91', 'dtsf:KwotaB': '21942901.29'},
#    'jin:M': {'dtsf:KwotaA': '6652581', 'dtsf:KwotaB': '1531794'},
#    'jin:O': {'dtsf:KwotaA': '25749584.91', 'dtsf:KwotaB': '20411107.29'}}},
#  'ZestZmianWKapitale': {'jin:I': {'dtsf:KwotaA': '386886309.92',
#    'dtsf:KwotaB': '392475202.63',
#    'jin:I_1': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#    'jin:I_2': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#   'jin:IA': {'dtsf:KwotaA': '386886309.92',
#    'dtsf:KwotaB': '392475202.63',
#    'jin:IA_1': {'dtsf:KwotaA': '51550',
#     'dtsf:KwotaB': '51550',
#     'jin:IA_1_1': {'dtsf:KwotaA': '0',
#      'dtsf:KwotaB': '0',
#      'jin:IA_1_1_A': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#      'jin:IA_1_1_B': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#     'jin:IA_1_2': {'dtsf:KwotaA': '51550', 'dtsf:KwotaB': '51550'}},
#    'jin:IA_2': {'dtsf:KwotaA': '369416939.63',
#     'dtsf:KwotaB': '376369014.17',
#     'jin:IA_2_1': {'dtsf:KwotaA': '17411107.29',
#      'dtsf:KwotaB': '-6952074.54',
#      'jin:IA_2_1_A': {'dtsf:KwotaA': '17411107.29',
#       'dtsf:KwotaB': '3047925.46',
#       'jin:IA_2_1_A_2': {'dtsf:KwotaA': '17411107.29',
#        'dtsf:KwotaB': '3047925.46'}},
#      'jin:IA_2_1_B': {'dtsf:KwotaA': '0',
#       'dtsf:KwotaB': '10000000',
#       'jin:IA_2_1_B_1': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '10000000'}}},
#     'jin:IA_2_2': {'dtsf:KwotaA': '386828046.92',
#      'dtsf:KwotaB': '369416939.63'}},
#    'jin:IA_3': {'dtsf:KwotaA': '6713',
#     'dtsf:KwotaB': '6713',
#     'jin:IA_3_1': {'dtsf:KwotaA': '0',
#      'dtsf:KwotaB': '0',
#      'jin:IA_3_1_B': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#     'jin:IA_3_2': {'dtsf:KwotaA': '6713', 'dtsf:KwotaB': '6713'}},
#    'jin:IA_4': {'dtsf:KwotaA': '0',
#     'dtsf:KwotaB': '0',
#     'jin:IA_4_1': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#     'jin:IA_4_2': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#      'jin:A_II_10': {'dtsf:KwotaA': '-19070.51', 'dtsf:KwotaB': '19070.51'}},
#     'jin:A_III': {'dtsf:KwotaA': '82755013.03', 'dtsf:KwotaB': '76315162.01'}},
#    'jin:B': {'jin:B_I': {'dtsf:KwotaA': '65771072.73',
#      'dtsf:KwotaB': '46009247.52',
#      'jin:B_I_1': {'dtsf:KwotaA': '11273503.85', 'dtsf:KwotaB': '7485039.14'},
#      'jin:B_I_2': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#      'jin:B_I_3': {'dtsf:KwotaA': '25275564.18',
#       'dtsf:KwotaB': '27283771.83',
#       'jin:B_I_3_A': {'dtsf:KwotaA': '25275564.18',
#        'dtsf:KwotaB': '27283771.83'},
#       'jin:B_I_3_B': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#      'jin:B_I_4': {'dtsf:KwotaA': '29222004.7', 'dtsf:KwotaB': '11240436.55'}},
#     'jin:B_II': {'dtsf:KwotaA': '-77788048.08',
#      'dtsf:KwotaB': '-60121246.58',
#      'jin:B_II_1': {'dtsf:KwotaA': '-56240875.53',
#       'dtsf:KwotaB': '-41346002.18'},
#      'jin:B_II_3': {'dtsf:KwotaA': '-226067.55',
#       'dtsf:KwotaB': '-114964.42',
#       'jin:B_II_3_A': {'dtsf:KwotaA': '-226067.55',
#        'dtsf:KwotaB': '-114964.42'},
#       'jin:B_II_3_B': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#      'jin:B_II_4': {'dtsf:KwotaA': '-21321105',
#       'dtsf:KwotaB': '-18660279.98'}},
#     'jin:B_III': {'dtsf:KwotaA': '-12016975.35',
#      'dtsf:KwotaB': '-14111999.06'}},
#    'jin:C': {'jin:C_I': {'dtsf:KwotaA': '60293701.55',
#      'dtsf:KwotaB': '60361324.95',
#      'jin:C_I_2': {'dtsf:KwotaA': '60293701.55', 'dtsf:KwotaB': '60361324.95'},
#      'jin:C_I_4': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'}},
#     'jin:C_II': {'dtsf:KwotaA': '-115328093.94',
#      'dtsf:KwotaB': '-117081431.14',
#      'jin:C_II_2': {'dtsf:KwotaA': '-1909999.95',
#       'dtsf:KwotaB': '-24090000.05'},
#      'jin:C_II_3': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#      'jin:C_II_4': {'dtsf:KwotaA': '-81723413.89', 'dtsf:KwotaB': '-74693402'},
#      'jin:C_II_5': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#      'jin:C_II_6': {'dtsf:KwotaA': '0', 'dtsf:KwotaB': '0'},
#      'jin:C_II_7': {'dtsf:KwotaA': '-2398448.73',
#       'dtsf:KwotaB': '-3009462.05'},
#      'jin:C_II_8': {'dtsf:KwotaA': '-29296231.37',
#       'dtsf:KwotaB': '-15288567.04'}},
#     'jin:C_III': {'dtsf:KwotaA': '-55034392.39',
#      'dtsf:KwotaB': '-56720106.19'}},
#    'jin:D': {'dtsf:KwotaA': '15703645.29', 'dtsf:KwotaB': '5483056.76'},
#    'jin:E': {'dtsf:KwotaA': '0',
#     'dtsf:KwotaB': '0',
#     'jin:E_1': {'dtsf:KwotaA': '23441.5', 'dtsf:KwotaB': '-26447.37'}},
#    'jin:F': {'dtsf:KwotaA': '10946342.16', 'dtsf:KwotaB': '5489732.77'},
#    'jin:G': {'dtsf:KwotaA': '26673428.95',
#     'dtsf:KwotaB': '10946342.16',
#     'jin:G_1': {'dtsf:KwotaA': '589750.23', 'dtsf:KwotaB': '2285467.25'}}}},
#  'DodatkoweInformacjeIObjasnieniaJednostkaInna': {'DodatkoweInformacjeIObjasnienia': {'dtsf:Opis': 'Informacja dodatkowa 2023.pdf',
#    'dtsf:Plik': {'dtsf:Nazwa': 'Informacja_dodatkowa_2023.pdf',
#     'dtsf:Zawartosc': '...'}},
#   'InformacjaDodatkowaDotyczacaPodatkuDochodowego': {'dtsf:P_ID_1': {'dtsf:RB': '32402165.91',
#     'dtsf:RP': '21942901.29'},
#    'dtsf:P_ID_2': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '0'}}},
#    'dtsf:P_ID_3': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '-35768075.72',
#       'dtsf:KwotaB': '-18351794.47',
#       'dtsf:KwotaC': '-17416281.25'},
#      'dtsf:RP': {'dtsf:KwotaA': '-29923093.27',
#       'dtsf:KwotaB': '-26269477.47',
#       'dtsf:KwotaC': '-3653615.8'}}},
#    'dtsf:P_ID_4': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '0'}}},
#    'dtsf:P_ID_5': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '0'}}},
#    'dtsf:P_ID_6': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '34800116.98',
#       'dtsf:KwotaB': '4002776.54',
#       'dtsf:KwotaC': '30797340.44'},
#      'dtsf:RP': {'dtsf:KwotaA': '58203989.37',
#       'dtsf:KwotaB': '14225065.75',
#       'dtsf:KwotaC': '43978923.62'}}},
#    'dtsf:P_ID_7': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '0'}}},
#    'dtsf:P_ID_8': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '0'}}},
#    'dtsf:P_ID_9': {'dtsf:Kwota': {'dtsf:RB': {'dtsf:KwotaA': '-23201806.15',
#       'dtsf:KwotaB': '-6286384.02',
#       'dtsf:KwotaC': '-16915422.13'},
#      'dtsf:RP': {'dtsf:KwotaA': '-31273561.63',
#       'dtsf:KwotaC': '-31273561.63'}}},
#    'dtsf:P_ID_10': {'dtsf:RB': '8232401.02', 'dtsf:RP': '18950235.76'},
#    'dtsf:P_ID_11': {'dtsf:RB': '1564156', 'dtsf:RP': '3600545'}}}}

# %%
def find_values(values_dict):
    for face0 in values_dict.keys():
        for face1 in values_dict[face0].keys():
            if "Kwota" in face1:
                print(f"{face0}:{values_dict[face0][face1]}")
            else:
                for face2 in values_dict[face0][face1].keys():
                    if "Kwota" in face2:
                        print(f"{face0}|{face1}:{values_dict[face0][face1][face2]}")
                    else:
                        for face3 in values_dict[face0][face1][face2].keys():
                            if "Kwota" in face3:
                                print(f"{face0}|{face1}|{face2}:{values_dict[face0][face1][face2][face3]}")
                            else:
                                for face4 in values_dict[face0][face1][face2][face3].keys():
                                    print(f"{face0}|{face1}|{face2}|{face3}:{values_dict[face0][face1][face2][face3][face4]}")
